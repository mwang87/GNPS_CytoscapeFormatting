# %%
"""Lets try to get all visual properties and save to json files ourselves"""

from py2cytoscape import cyrest

cytoscape=cyrest.cyclient()
cytoscape.version()
cytoscape.network.list()


cytoscape.styles.getStyleFull("Sample2", verbose=True).json()

# %%
"""Deprecated"""

from py2cytoscape.data.cyrest_client import CyRestClient
import py2cytoscape

cy  = CyRestClient()
network1 = cy.network.create_from("test.graphml")

mystyle = cy.style.create("ClassDefault")

# %%
#pip3 install git+https://github.com/cytoscape/py2cytoscape.git

# %%
from py2cytoscape import cyrest

cytoscape=cyrest.cyclient()
cytoscape.version()
cytoscape.network.list()
#cytoscape.vizmap.apply(styles="Sample1")
#cytoscape.vizmap.load_file(afile="./styles.xml", verbose=True)
# Out:
# apiVersion v1
# cytoscapeVersion 3.7.1
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-6-320661a4ae85> in <module>()
#       5 cytoscape.network.list()
#       6 #cytoscape.vizmap.apply(styles="Sample1")
# ----> 7 cytoscape.vizmap.load_file(afile="./styles.xml", verbose=True)
#
# /usr/local/lib/python3.6/dist-packages/py2cytoscape/cyrest/vizmap.py in load_file(self, afile, verbose)
#      81         """
#      82
# ---> 83         network=check_network(self,network,verbose=verbose)
#      84         PARAMS=set_param(["afile"],[afile])
#      85         response=api(url=self.__url+"/load file", PARAMS=PARAMS, method="POST", verbose=verbose)
#
# UnboundLocalError: local variable 'network' referenced before assignment

# %%
# Out:
# apiVersion v1
# cytoscapeVersion 3.7.1
# 'http://localhost:1234/v1/styles/Sample2'
# response status 200
# 'http://localhost:1234/v1/styles/Sample2'
# {'defaults': [{'value': 10.0, 'visualProperty': 'COMPOUND_NODE_PADDING'},
#   {'value': 'ROUND_RECTANGLE', 'visualProperty': 'COMPOUND_NODE_SHAPE'},
#   {'value': 'org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@51516928',
#    'visualProperty': 'DING_RENDERING_ENGINE_ROOT'},
#   {'value': 'DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)',
#    'visualProperty': 'EDGE'},
#   {'value': None, 'visualProperty': 'EDGE_BEND'},
#   {'value': True, 'visualProperty': 'EDGE_CURVED'},
#   {'value': '', 'visualProperty': 'EDGE_LABEL'},
#   {'value': '#000000', 'visualProperty': 'EDGE_LABEL_COLOR'},
#   {'value': 'SansSerif.plain,plain,10',
#    'visualProperty': 'EDGE_LABEL_FONT_FACE'},
#   {'value': 10, 'visualProperty': 'EDGE_LABEL_FONT_SIZE'},
# ...
